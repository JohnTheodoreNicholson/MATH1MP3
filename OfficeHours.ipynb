# %%
s = "1string"
type(s[0])
type(s[1])
# Out:
# str

# %%
t = (1,'4')

# %%
# R^2 -> R^2
# (x,y) -> (x+y, x-y)

def f(x,y):
    return x+y, x-y

t = f(1,2)
print(t)
out1, out2 = t
print(out1)
# Out:
# (3, -1)
# 3

# %%
t = 1,2,3
print(t)
# Out:
# (1, 2, 3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
L = [1,2,3,4]
i = 0

while i < len(L):
    L[i]

# %%
t = t,4
t[0]
# Out:
# ((1, 2, 3, 4), 4)

# %%
L = [4,1]

for i in L:
    L = L.append(i)
    print(i)
# Out:
# 4

# %%
i = 1

while i<f(i):
    print(i)
