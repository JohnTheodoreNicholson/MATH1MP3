# %% [markdown]
# ## Instructions
# * Fill in your name, macID, and student number between quotes below.
# * Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
# * The use of generative AI (ChatGPT, Claude, CoPilot, etc) is not allowed for this homework. The instructors will ask students suspected of using generative AI to go through the code line by line and explain it.
# * Code is a form of communication and is highly personal. It is easy to spot similar assignments.
# * You may remove any lines of the form `raise NotImplementedError()`.

# %%
NAME =  ""
MACID = ""
STUDENT_NUMBER = ""

# %%
assert NAME != ""
assert MACID != ""
assert STUDENT_NUMBER != ""

# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Question 1
#
# Create a variable `i` and assign it the value 2026

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Verification: this cell should run without errors.
assert type(i) == int
assert i == 2026

# %% [markdown]
# ## Question 2
# Increment `i` by 1

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Verification: this cell should run without errors.
assert i == 2027

# %% [markdown]
# ## Question 3
# Compute the remainder of the division of `i` by 10

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Question 4
#
# Divide `i` by 3 and store the result in a variable named `j` without altering the value of the variable `i`.

# %%
#YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Question 5
# Round `i` to the **nearest** integer.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Question 6
#
# Explain why the print statements in the following code print different texts

# %%
theAnswer = "42"
print(theAnswer)
print("theAnswer")

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Question 7
#
# Explain why the following code generates an error.

# %% [markdown]
# ```
# alpha = 1
# beta  = 2.3
# mu    = alpha + beta
# lambda = 1 - mu
# sigma = alpha
# ```

# %% [markdown]
# YOUR ANSWER HERE
