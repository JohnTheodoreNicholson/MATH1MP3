# %% [markdown]
# ## sympy problems
# This one is easy...
# Download the excellent and free openstax calculus textbook from [this link](https://openstax.org/details/books/calculus-volume-1) and solve any problem from eth following sections using sympy:
# * 2.3: The limit laws
# * 2.4: Continuity
# * 3-2 - 3.6, 3.9: Derivatives
# * 5.1 - 5.7, 6.1 - 6.9: Integrals
