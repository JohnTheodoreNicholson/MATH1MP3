# %% [markdown]
# # Practice Final Exam

# %% [markdown]
# ## Question 1:
# plot the function $f(x) = \frac{1}{1+\cos^2 x}$ on the interval $[-\pi, \pi]$.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Question 2:
# Compute $f'$ using sympy

# %%
sympy.diff(f,x)

# %% [markdown]
# ## Question 3:
# Compute $\int_{-\pi}^\pi f(x)\, dx$ using sympy of scipy

# %% [markdown]
# ## Question 4:
# write a function `ndApply` that given a python function `f` and an ndarray `B` of arbitrary shape returns a ndarray of identical shape whose elements are obtained by applying `f` to those of `A`. Your function should not have side effects (i.e. not modify `A`).
#
# Note that simply returning `f(A)` will not work (try it with the example below).

# %%
import numpy as np
def f(x):
    return max(x, 0)

def ndapply(f, A):
    # this won't work
    return f(A)

A = np.random.randint(low = -10, high = 11, size = (2,3,4))
ndapply(f, A)

# %%
L = [1,2,3]

# %%
for a in enumerate(L):
    print(a)

# %%
def ndapply(f,A):
    B = np.empty(A.shape)
    for idx,el in np.ndenumerate(A):
        B[idx] = f(el)
    return B

# %% [markdown]
# ## Question 5:
# Write a python function `sums` which, given a list `l` returns a tuple consisting of the sum of the values of `l` with even indices, and that with odd indices.
#
# For instance, if `l = [1, 2, 3, 4, 12]`, you should get `sum(l) = (1 + 3 + 12, 2 + 4)`

# %% [markdown]
# ## Question 6:
# Write a function `makeDict` which, given a tuple of keys `k` and a tuple of values `v`, create a dictionary whose keys are `k` and values are `v`.
# For instance if `k = ('name', 'age', 'weight')` and `v = ('Marvin', 12, 25)`, you should get `makeDict(k,v) = {'name':'Marvin', 'age':12, 'weight':25}`.

# %%
def makeDict(k,v):
    d ={}
    for key,value in zip(k,v):

# %% [markdown]
# ## Question 7:
# Create a pandas DataFrame from the `titanic.csv` file used in class and answer the following questions:
# * List the names of the males survivors with a 3rd class ticket aged 20-30?
# * Of the following groups, which had teh highest survival rate:
#     * Men all age
#     * Women all age
#     * Children (less that 18 year old), all gender
#     * First class passengers (all age and gender)

# %%
import pandas as pd
df = pd.read_csv(titanic.csv)

menrate = df[(df['Sex']== 'male') & (df['Pclass'] == 3['Survived']) & (df['Age'] <= 30) & (df['Age'] >=20)].to_list

{}

# %% [markdown]
# ## Question 8:
# * Create a polynomial whose roots are the solution of the following linear system of equations:
# $$
# \left\{
# \begin{matrix}
# x_0 + x_1 + x_2 + x_3 & = & 6\\
# x_0 + 2x_1 + 2 x_2 + 2x_3 & = & 12\\
# x_0 - x_1 + x_2 - x_3 & = & -2\\
# 2x_0 + x_1 + 2 x_2 - x_3 & = & 0
# \end{matrix}
# \right.
# $$
# * Find all it local extrema

# %% [markdown]
# ## Question 9:
# Write a function `addExt` which given an arbitrary number of file prefixes given as a positional arguments and an extension given as the keyword argument `extension`, and returns a list of file names. If no extension is given, use '.txt'.
# For instance, you should have
# * `addExt('readme', 'license', 'install', extension = 'md') = ['readme.md', 'license.md', 'install.md']`
# * `addExt('info', extension = 'ini') = ['info.ini']`
# * `addExt('exam1', 'exam2') = ['exam1.txt', 'exam2.txt']`

# %% [markdown]
# ## Question 10:
# Write a function `semiNorm(f,a,b)` which given a  function `f` and an interval with end points `a` and `b` returns an approximation of
# $$
# \int_a^b f'(x)^2\, dx.
# $$
# You can either use sympy or scipy
