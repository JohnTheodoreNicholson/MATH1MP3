# %% [markdown]
# # Practice Midterm 1

# %% [markdown]
# ## Question 1
# Compute
# $$
#     \sum_{i=1}^{n} \frac{1}{i} \sin\frac{i\pi}{n},
# $$
# when $n=1000$.
# Store the result in the variable `partialSum`

# %%
import math
# YOUR CODE HERE
raise NotImplementedError()
print(partialSum)

# %%
import numpy as np
assert np.isclose(partialSum, 1.8503659938562658)

# %% [markdown]
# ## Question 2
#
# You are given a list `L` of numbers. Compute the minimum value `Lmin` and maximum values `Lmax` of all elements in `L`. Do not use python built-in min or max functions.
#
# The cell below will compute a new list every time it is run. You do not need to understand its content or alter it in any way.

# %%
import numpy as np
n = np.random.randint(low = 0, high = 21)
L = np.random.random(n)
print(L)

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
import numpy as np
assert np.isclose(Lmin,min(L))
assert np.isclose(Lmax,max(L))

# %% [markdown]
# ## Question 3
# The Cobb-Douglass equation in economics states that
# $$
# Y(L,K) = A L^\alpha K^\beta
# $$
# where $A$, $L$, $K$, and $Y$ are some quantities and $\alpha$ and $\beta$ are some parameters. It does not really matter what these are or what they represent...
# You are given values of $A$, $L$, $K$, $Y$, $\alpha$, and $\beta$. Write a python expression that computes $Y$.
# As before the values of the parameters will change every time you run the cell below

# %%
import numpy as np
A = np.random.random()
L = np.random.random()
K = np.random.random()
alpha = np.random.random()
beta = np.random.random()

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Your code is being tested, but you are not shown the tests
assert not Y == None

# %% [markdown]
# ## Question 4
# A geometric sequence with first term $a$ and ratio $r$ is defined as:
# $$
# a_0 = a,
# $$
# and
# $$
# a_{n+1} = r.a_n.
# $$
#
# You are given random values of $a$, $r$, and $n$. Write a python code that computes $a_n$ and store the result in the variable `an` using loops. Do not use the direct formula for $a_n$ as a fuction of $a$, $r$, and $n$ even if you know it...

# %%
import numpy as np
a = np.random.uniform(low = -10, high = 10)
r = np.random.uniform(low = 0.75, high = 1.25)
n = np.random.randint(low = 10, high = 101)
print(f'a: {a}')
print(f'r: {r}')
print(f'n: {n}')

# %%
# YOUR CODE HERE
raise NotImplementedError()
print(an)

# %%
# Your code is being tested, but you are not shown the tests

# %% [markdown]
# ## Question 5
# You are given a long list of random integer numbers `L`. Find the index `idx` of the first number in `L` that is a multiple of 7 but not of 3.
#
# For instance, if `L=[1, 35, 21]`, `idx` should be 1.

# %%
L = np.random.randint(low = 0, high = 1000, size = 100)
L[-1] = 14

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
assert L[idx]%7 == 0 and L[idx]%3 != 0
for i in range(idx):
    assert L[i]%3 == 0 or L[i]%7 != 0

# %% [markdown]
# ## Question 6
#
# You are given a string `paragraph` consisting of a full paragraph taken from Mary Shelley's "Frankenstein" and a  letter `l` of the alphabet. Compute the number of times `n` at which the letter `l` appears in your paragraph. Store the result in the variable `nl`
#
# You are not allowed to use the function `count`.

# %%
# This commands extracts one paragraph from a file containing the entire novel
with open("Frankenstein.txt", "r") as f:
    Franky = [par.replace("\n", " ").lower() for par in f.read().split("\n\n") if len(par) > 50 and not par.startswith(" Letter")]
paragraph = Franky[np.random.randint(len(Franky))]
print(f"paragraph: \n   {paragraph}")
l = "qazwsxedcvfrtgbnhyujmkilop"[np.random.randint(26)]
print(f"letter: {l}")

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
assert nl == paragraph.count(l)
