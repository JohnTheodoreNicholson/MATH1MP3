# %% [markdown]
# # Pandas practice problems
#
# ## The grades file
# Import the grade file "Notebooks/grades.csv" in a pandas dataframe to answer the following questions:
# * Compute the final grade for the class using the best for scheme I and II:
#    - scheme I: quiz: 10%, HW 30%, midterm, final 20% each
#    - scheme II: quiz: 10%, HW 30%, midterm: 40%, best of 2 midterm: 40%
# * What proportion of students scored better on their midterms (average of both grades) than on their final?
# * What are the mean and standard deviation of the grades in each categories?
#
# ## The titanic data file
#
# Import the titanic passenger list file 'Notebooks/titanic.xls' in a pandas dataframe to answer the following questions:
#
# * What is the overall survival rate for male vs. female?
# * How does the survival rate of women and children (< 18 year) compare to the overall rate?
# * What was the average fare for 1st, 2nd, and 3rd class passengers?
# * List the names of the males survivors with a 3rd class ticket aged 20-30?
#
# ## The gas price file
#
# Import the gas price file "Notebooks/1810000101_databaseLoadingData.csv" in a pandas dataframe to answer the following questions:
#
# * In which month was gas the most expensive in 2020 across the whole country? For each province?
# *  In which province was gas the cheaper in average over the entire time period? Each year since 2016?
#
#
# ## Higher education spending per province
# Go to [Statistics Canada website](https://statcan.gc.ca) and search for data sets named "Annual expenditure by educational institutions per student, by educational level". This is released annually, so you should be able to get many data sets. Download as many sets as you can.
#
# Build a *single* dataFrame containing all this data, then try to answer the following question:
# * What was the total spending for colleges, CEGEP, Bachelor and above in each province or territory over the entire time range?
# * Sort the provinces and territories by total higher education spending over the last 5 years.
# * Sort the provinces and territories by higher education spending *per capita* over the last 5 years. You will need population data, which I am sure you can locate on statcan.
# * Sort the provinces and territories by total higher education spending *per student* over the last 5 years. You will need total number of student data, for instance from table 37-10-0275-02. I am sure that there is a better source.
#
# ## University tuition
# Find a data table labelled "Canadian students, tuition and additional compulsory fees, by level of study" on statcan and import the data for the 2005 to 2025 period.
#
# * For each province, what was the tuition annual and total increase rate over this period?
# * How does Ontario compare to the national average?
# * How does tuition increase compare to the overall inflation?
#
# ## Gas prices
# Download the [gas price data set from statcan](https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1810000101)
# and answer the following questions:
# * Plot the seasonal price of gas in each province over a given time range
# * Which province had teh cheapest and most expensive gas price each month in 2021? in 2025?
# *
# Try to find a cost of living index for teh sam period (I am sure statcan has it). Does gas price increase faster or slower than teh overall cost of living?
#
#
# ## Generate an "age pyramid" of the population of Canada at any given time over the last century or so, similar to the one [there](https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/dv-vd/pyramid/index-eng.cfm)
#
#
# ## More practice problems online:
# * https://machinelearningplus.com/python/101-pandas-exercises-python/
# * https://www.geeksforgeeks.org/python/pandas-practice-excercises-questions-and-solutions/
