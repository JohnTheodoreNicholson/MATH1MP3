# %% [markdown]
# # Polynomials
# Just like we saw in the most recent assignment, polynomials can be represented by their coefficients. `numpy.polynomial` implements these and most of the operations that one may way to apply to polynomials.

# %%
import numpy as np
from numpy.polynomial import Polynomial

# %%
# Create a polynomial from its coefficients
P = Polynomial([1,2,3,4])
print(P)
type(P)
# Out:
# 1.0 + 2.0·x + 3.0·x² + 4.0·x³
# numpy.polynomial.polynomial.Polynomial

# %%
# Polynomials behave like functions in that they can be evaluated
print(f"P(0) = {P(0)}")
print(f"P(1) = {P(1)}")
# Out:
# P(0) = 1.0
# P(1) = 10.0

# %%
# all agrebraic operations are implemented

Q = Polynomial([3,2,0,3])
print('P+Q:  ', P+Q)
print('P*Q:  ', P*Q)
print('P**2: ', P**2)
# Out:
# P+Q:   4.0 + 4.0·x + 3.0·x² + 7.0·x³
# P*Q:   3.0 + 8.0·x + 13.0·x² + 21.0·x³ + 14.0·x⁴ + 9.0·x⁵ + 12.0·x⁶
# P**2:  1.0 + 4.0·x + 10.0·x² + 20.0·x³ + 25.0·x⁴ + 24.0·x⁵ + 16.0·x⁶

# %%
# We can also recover the copefficients from a polynomial
R = P**2
print(f"R.coef {R.coef}, {type(R.coef)}")
# Out:
# R.coef [ 1.  4. 10. 20. 25. 24. 16.], <class 'numpy.ndarray'>

# %%
# derivatives and integrals also are implemented
Q = P.deriv()
print("P': ", Q)
R = P.integ()
print("int P: ", R)
# Out:
# P':  2.0 + 6.0·x + 12.0·x²
# int P:  0.0 + 1.0·x + 1.0·x² + 1.0·x³ + 1.0·x⁴

# %% [markdown]
# ### Application: Lagrange interpolation:
# Given $(x_0, x_1, x_2)$ pairwise distinct and $(y_0, y_1, y_2)$, find $P\in\mathbb{P}^2$ such that $P(x_i) = y_i$ for $y = 0, 1, 2$.
#
# * The hard way: write $P(x) = a_0 + a_1x + a_2 x^2$, substitute $P(x_i) = y_i$ and solve a system of three equations with three unknowns.
# * The easy way: build three polynomials of degree 2 $\varphi_0, \varphi_1, \varphi_2$ such that $\varphi_i(x_j) = \delta_{i,j}$, and notice that $P(x) = y_0 \varphi_0(x) + y_1 \varphi_1(x) + y_2 \varphi_2(x)$. Construct the $\varphi_i$ from their roots, then normalize them.

# %%
P = Polynomial.fromroots([-1,0,1])
print(P)
print(P(-1), P(0), P(1))
# Out:
# 0.0 - 1.0·x + 0.0·x² + 1.0·x³
# 0.0 0.0 0.0

# %%
def LagrangeInterpolation(X, Y):
    # construct phi_0, phi_1, phi_2
    phi_0 = Polynomial.fromroots([X[1], X[2]]) # construct (x-x1)*(x-x2)
    phi_1 = Polynomial.fromroots([X[0], X[2]]) # (x-x0)*(x-x2)
    phi_2 = Polynomial.fromroots([X[0], X[1]]) # (x-x0)*(x-x1)
    phi_0 = phi_0 / phi_0(X[0]) # normalize value at x0
    phi_1 = phi_1 / phi_1(X[1]) # normalize value at x1
    phi_2 = phi_2 / phi_2(X[2]) # normalize value at x2
    # Now we have a polynomial that is 1 at x0, x1, and x2, so we can scale to 
    # meet the desired goal.
    return Y[0] * phi_0 + Y[1] * phi_1 + Y[2] * phi_2

# %%
import numpy as np
import matplotlib.pyplot as plt

def q(x):
    return 1.776*x + 8*x**2-6*x**3 + x**4
x = np.linspace(-2,2,1000)
plt.plot(x,q(x))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
X = [1,2,3]
Y = [-1, 0, 2]

# %%
Q = LagrangeInterpolation(X,Y)
print(Q)
print(Q(X))
# Out:
# -1.0 - 0.5·x + 0.5·x²
# [-1.  0.  2.]

# %%
import matplotlib.pyplot as plt
# %matplotlib widget
fig, ax = plt.subplots()
X0 = np.linspace(0, 5, 201)

X = [1,2,3]
Y = [-1, 0, 2]
ax.plot(X0,Q(X0))
ax.scatter(X,Y)

Y = [-1,2,-1]
ax.plot(X0,LagrangeInterpolation(X,Y)(X0))
ax.scatter(X,Y)

plt.show(block = False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dir(P)
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__array_ufunc__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_abc_impl',
#  '_add',
#  '_der',
#  '_div',
#  '_fit',
#  '_format_term',
#  '_fromroots',
#  '_generate_string',
#  '_get_coefficients',
#  '_int',
#  '_line',
#  '_mul',
#  '_pow',
#  '_repr_latex_',
#  '_repr_latex_scalar',
#  '_repr_latex_term',
#  '_roots',
#  '_str_term_ascii',
#  '_str_term_unicode',
#  '_sub',
#  '_subscript_mapping',
#  '_superscript_mapping',
#  '_symbol',
#  '_use_unicode',
#  '_val',
#  'basis',
#  'basis_name',
#  'cast',
#  'coef',
#  'convert',
#  'copy',
#  'cutdeg',
#  'degree',
#  'deriv',
#  'domain',
#  'fit',
#  'fromroots',
#  'has_samecoef',
#  'has_samedomain',
#  'has_sametype',
#  'has_samewindow',
#  'identity',
#  'integ',
#  'linspace',
#  'mapparms',
#  'maxpower',
#  'roots',
#  'symbol',
#  'trim',
#  'truncate',
#  'window']
