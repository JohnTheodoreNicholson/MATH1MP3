# %% [markdown]
# # Objects
#
# We have thus far seen a few different kinds of data that Python can deal with. These individual bits of data like the integer `5` or the string `Hello world` are called **objects**.
#
# In Python, we break objects up into groups called **types**. That is, Python recognizes that `3` and `4` have more in common, than `4` and `Hello world`.
#
# The `type` command can be used to query the type of an object:

# %%
a = 1
s = "this is a message"
t = 2 + 3J
print('type(a): ', type(a))
print('type(s): ', type(s))
print('type(t): ', type(t))
# Out:
# type(a):  <class 'int'>
# type(s):  <class 'str'>
# type(t):  <class 'complex'>

# %% [markdown]
# Another big perk of having types is that we can implement **methods**. Methods are special functions which only work for certain classes of objects. For instance, both strings and integers have an addition method, but addition works differently in each context.

# %% [markdown]
# ## Strings again
# ### String indexing
# It is possible to extract parts of a string, using *indexing*, denoted using square brackets '[]'.
# * `s[0]` is the first character in `s`, `s[1]` the second etc.
# * `s[-1]` is the last character in `s`, `s[-2]`, second to last etc
#
# Note that in python, indices start from 0, so the valid range of indices for a string of length $n$ is $0$ to $n-1$.
#
# The function `len` can be used to query the length of a given string

# %%
print('s:    ', s)
print('len(s): ', len(s))
print('s[0]: ',s[0])
print('s[1]: ', s[1])
# Out:
# s:     this is a message
# len(s):  17
# s[0]:  t
# s[1]:  h
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 print('s[0]: ',s[0])
#       4 print('s[1]: ', s[1])
# ----> 5 print('s[17]: ', s[17])
#
# IndexError: string index out of range

# %%
print('s:    ', s)
print('s[-1]: ', s[-1])
print('s[-1]: ', s[-2])
# Out:
# s:     this is a message
# s[-1]:  e
# s[-1]:  g

# %% [markdown]
# Indexing can be used to extract part of a string. Given a string `s`, `s[a:b]` denotes the string consistings of characters at position `a` to `b` (excluded).
#
# `len(s)` return the length of `s`, i.e. number of characters in `s`

# %%
print('s[0:3]:  ', s[0:3])
print('s[3:-1]: ', s[3:17])
print(len(s))
# Out:
# s[0:3]:   thi
# s[3:-1]:  s is a message
# 17

# %% [markdown]
# If `a` is omitted, `s[:b]` is to be understood as all positions up to (exclusing) `b`.
# If `b` is omitted, `s[a:]` is to be understood as all starting with `a`.

# %%
print('s[:3]: ',s[0:3:2])
print('s[3:]: ',s[3:])

# %% [markdown]
# Optionally, one can also specify a stride: `s[a:b:c]` is a string containing characters at indices `a`, `a+c`, `a+2*c`, ... `b` in `s`.

# %%
numbers = '0123456789'
print(numbers)
print('numbers[0:10:2]: ', numbers[0:10:2])
print('numbers[1:10:2]: ', numbers[1:10:2])
# Out:
# 0123456789
# numbers[0:10:2]:  02468
# numbers[1:10:2]:  13579

# %% [markdown]
# Note that the stride can be negative, in which case one needs to get `a>b`

# %%
print('numbers[10:0:-1]: ', numbers[10:0:-1])
# Out:
# numbers[10:0:-1]:  987654321

# %% [markdown]
# Note that the rules for omitted bounds still apply when a stride is specified:

# %%
print('numbers[0:10:2]: ', numbers[0:10:2])
print('numbers[:10:2]:  ', numbers[:10:2])
print('numbers[::2]:    ', numbers[::])

# %% [markdown]
# ### A classical example: reversing a string.

# %%
test1 = 'a test string'

test1[-1:-len(test1)-1:-1]
# Out:
# 'gnirts tset a'

# %% [markdown]
# ### Important:
# Python strings are *immutable*. This means that it is not possible to use indexing to modify a string.

# %%
msg = "this is a test"
msg[0] = 'T'
# Out:
# 't'

# %%
msg = "this is a test"
# You cannot capitalize the first character this way;
msg[0] = "T"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 msg = "this is a test"
#       2 # You cannot capitalize the first character this way;
# ----> 3 msg[0] = "T"
#
# TypeError: 'str' object does not support item assignment

# %%
msg = 'This is a test'

# %% [markdown]
# ## 1.2 F-string
#
# Nothing R-rated here... 'f' stands for 'formatted'!
#
# In f-strings, expression in curly braces (`{}`) are *replacement fields* that are substituted.

# %%
n = 8
animal = 'cat'
print(f'A {animal} year is worth {n} human years')
# Out:
# A cat year is worth 8 human years

# %% [markdown]
# ## Objects and methods
# Python 'objects' are more than different 'types'. In particular object *encapsulate* 'data' and 'methods'. You can think of the data, as the 'value' of a string. Methods are operation that are applied to the data or properties of that data.
#
# The `dir` command will print all methods implemented for a object.

# %%
(5).__add__(7)
5 + 7
# Out:
# 12

# %%
'str1'.__add__('str2')
# Out:
# 'str1str2'

# %%
msg = "this is a test"
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
msg = "this is a test"
print(msg.capitalize())
print(msg.upper())
# Out:
# This is a test
# THIS IS A TEST

# %%
s = '1,2,3'
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# ### Playing with string methods

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
test1 = 'tEst2 StRing'
test2 = '12345'

print(test1.isalnum())
print(test2.isalnum())

print(test1.swapcase())
# Out:
# False
# True
# TeST2 sTrING
