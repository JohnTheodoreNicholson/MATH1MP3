# %% [markdown]
# # Functions
#
# Functions are an essential step towards write *reusable code*. If the same block of code is reused repeatedly, a function is a way to repeat it multiple code without rewriting it each time. We have encountered many functions already. For instance, when we execute the command `print("Hello world")`, we call a python function (`print`) which does whatever is needed so that he message "hello world" appears in our notebook. In this context, we say that we *call* the function `print` with argument `"hello world"`.

# %% [markdown]
# ## Defining and calling a function:
#
# A function is defined using the keyword `def` for instance:

# %%
def sayHello():
    print("Hello!")
    print("Some other things...")
    print("More lines to run")
print("Hello")
# Out:
# Hello

# %% [markdown]
# This creates a function of name `sayHello`. It is important to note that **everything** (everything user creatable at least) is an object in Python. This means that function names are not special names, they act exactly as variable names. So, we should be careful not to mix and match variable names and functions names.
#
# **Aside:** This is an instance of what is called *duck typing* in Python (*if it quacks like a duck, and walks like a duck, its probably a duck*). That is, in Python nothing has a *static type*, the type of an object is inferred from what it can do. For example, a type is a *container type* if it implements the `__contains__()` method (`i in L`). In the same way, an object is a function if it is **callable**.

# %% [markdown]
# The *body* of the function (*i.e.* everything that it should do) is denoted through indentation.
# Note the code *inside* the function is not executed here. For that, we need to *call* the function:

# %%
sayHello()
# Out:
# Hello!
# Some other things...
# More lines to run

# %%
sayHello()
# Out:
# Hello!
# Some other things...
# More lines to run

# %%
sayHello()
# Out:
# Hello!
# Some other things...
# More lines to run

# %% [markdown]
# ## Arguments
# The example above is a bit limited. A better use of function is to perform actions that depend on some parameters. This is typically done by *passing arguments* to a function.
#
# Consider the example below:

# %%
def printRectangleArea(width, height):
    print(f"the area of a {width} x {height} rectangle is {width * height}")

# %% [markdown]
# We can now execute the function multiple times for different values of `width` and `height`:

# %%
printRectangleArea(2, 'str')
printRectangleArea(1, 5)
printRectangleArea(2, 3)
printRectangleArea(10, 2)
# Out:
# the area of a 2 x str rectangle is strstr
# the area of a 1 x 5 rectangle is 5
# the area of a 2 x 3 rectangle is 6
# the area of a 10 x 2 rectangle is 20

# %% [markdown]
# Here the variables `width` and `height` behave like the independent variable of a mathematical function. They don't have a real meaning *per se*. They only exist inside the function `printRectangleArea` where they take the value that was *passed* when the function was called. We say that the *scope* of these variables is limited to the function

# %%
del height

# %%
printRectangleArea(1, 2)
print('height is ', height)
# Out:
# the area of a 1 x 2 rectangle is 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 printRectangleArea(1, 2)
# ----> 2 print('height is ', height)
#
# NameError: name 'height' is not defined

# %%
def aFunction():
    x = 5
    y = 2
    z = 1.7
aFunction()
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       4     z = 1.7
#       5 aFunction()
# ----> 6 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Python is a bit special amongst programming languages in that it does not care about the type of the arguments of a function (this is called a polymorphic language).
# This can be nice in some cases, for instance:

# %%
def printSum(a,b):
    print(f'{a} + {b} = {a+b}')

printSum(1,2)
printSum(1.23, 3.45)
printSum("hello", " world")
printSum(2, "hello")
# Out:
# 1 + 2 = 3
# 1.23 + 3.45 = 4.68
# hello +  world = hello world
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       5 printSum(1.23, 3.45)
#       6 printSum("hello", " world")
# ----> 7 printSum(2, "hello")
#
# Cell In[21], line 2, in printSum(a, b)
#       1 def printSum(a,b):
# ----> 2     print(f'{a} + {b} = {a+b}')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
printSum(1, "a")

# %% [markdown]
# It is however considered good practice to indicate the type of variables that a function expects, so that somebody reading code understands the intent of the author. In the previous case, if what we intended was only to add integers, a better definition of the function would be:

# %%
def printSum2(a : int, b : int):
    print(f'{a} + {b} = {a+b}')

printSum2(1,2)
printSum2('hello','world')
# Out:
# 1 + 2 = 3
# hello + world = helloworld

# %% [markdown]
# Note that this does not affect the ability of our function to take other kind of arguments. It just makes it easier to read for others (like the professors and TA who will grade your work)...

# %%
printSum2(1.23, 3.45)
printSum2("hello", " world")
# Out:
# 1.23 + 3.45 = 4.68
# hello +  world = hello world

# %%
def superInterestingFunction(a : float):
    print(f"If you double {a} you will get {2*a}")

superInterestingFunction(2)
print(a)
# Out:
# If you double 2 you will get 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       2     print(f"If you double {a} you will get {2*a}")
#       4 superInterestingFunction(2)
# ----> 5 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Return values

# %% [markdown]
# Functions are often used to 'compute' a quantity that we may want to reuse instead of just doing something. Back to the addition example, maybe we want to reuse the result of this function. In order to do this, we need to tell the function to *return* a result:

# %%
def addInt(a: int, b: int) -> int:
    sum = a + b
    return sum

# %%
def badaddInt(a , b):
    print(a + b)
    return None

# %%
c = badaddInt(1,2)
print(c)
# Out:
# 3
# None

# %%
c = addInt(1, 2)
print(c)
# Out:
# 3

# %% [markdown]
# We could also have done

# %%
print(addInt(1, 2))

# %% [markdown]
# In your vector calculus class, you will study functions that given a scalar, return a vector. Similarly, python functions can return results of any type, or even several results. See for instance

# %%
def sumAndProduct(a: float, b: float) -> tuple [float, float]:
    return a + b, a * b

# %%
print(sumAndProduct(0.0,3.42))
print(type(sumAndProduct(0.0,3.42)))
sum, product = sumAndProduct(0.0,3.42)
print(sum)
print(product)
# Out:
# (3.42, 0.0)
# <class 'tuple'>
# 3.42
# 0.0

# %%
def badFunction(a : int) -> None:
    print(a)
    return None

# %%
print(badFunction(5))
# Out:
# 5
# None

# %% [markdown]
# The annotations of the form `a : float` in the code above are called **type annotations** or **type hints**. These are simply useful for the reader to understand the intended use of the function. However, as Python is a **duck typed** or **dynamically typed** language, it will not complain if we go against our type hints!

# %%
sumAndProduct(2,3)
# Out:
# (5, 6)

# %%
s,p = sumAndProduct(2,3)
print(s, p)
# Out:
# 5 6

# %%
(s,p) = sumAndProduct(2,3)
print(s, p)

# %% [markdown]
# ## Examples
#
# Implement a function called `dotProduct(x,y)` which takes as input two tuples of length 3 each (representing vectors), and returns their dot product.

# %%
# YOUR CODE HERE
def dotProduct(x : tuple[int,int,int], y : tuple[int, int, int]) -> int:
    #unpack tuples
    x1, x2, x3 = x
    y1, y2, y3 = y
    return x1*y1 + x2*y2 + x3*y3

# %%
s = (1,2,3)
t = (0,1,0)
print(dotProduct(s,t))
# Out:
# 2

# %%
help(dotProduct)
# Out:
# Help on function dotProduct in module __main__:
#
# dotProduct(x: tuple[int, int, int], y: tuple[int, int, int]) -> int
#     # YOUR CODE HERE

# %%
x = (1,2)
y = (3,4)

print(dotProduct(x,y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 4
#       1 x = (1,2)
#       2 y = (3,4)
# ----> 4 print(dotProduct(x,y))
#
# Cell In[41], line 4, in dotProduct(x, y)
#       2 def dotProduct(x : tuple[int,int,int], y : tuple[int, int, int]) -> int:
#       3     #unpack tuples
# ----> 4     x1, x2, x3 = x
#       5     y1, y2, y3 = y
#       6     return x1*y1 + x2*y2 + x3*y3
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# Implement a function called `matAdd(M,N)` which takes as input two $n\times n$ arrays represented as nested lists and returns their sum as a nested list.

# %%
M = [[1,2],[3,4]]
M[0][0]
M[0][1]
M[1][0]
M[1][1]

# %%
# working implementation
# But destroys information in M
def matAdd_2by2(M,N):
    sum = M 
    for i in range(2):
        for j in range(2):
            sum[i][j] += N[i][j]
    return sum

# %%
M = [[1,2],[3,4]]
N = [[-1,-2],[-3,-4]]

print(matAdd_2by2(M,N))
# Out:
# [[0, 0], [0, 0]]

# %%
# without destroying M
def matAdd_2by2(M,N):
    sum = [[0,0],[0,0]]
    for i in range(2):
        for j in range(2):
            sum[i][j] += M[i][j] + N[i][j]
    return sum

# %%
M = [[1,2],[3,4]]
N = [[-1,-2],[-3,-4]]

print(matAdd_2by2(M,N))
# Out:
# [[0, 0], [0, 0]]

# %%
def matAdd(M,N):
    # CODE HERE
    return None

# %% [markdown]
# **Question:** Can we do this without changing $M$ or $N$?

# %%
M = [[1,2,3],[4,5,6]]
N = M.copy()

M[0][0] = 5
print(M)
print(N)

# %% [markdown]
# # Tuesday July 14th 2026
#
# ## Announcements
# - Test 1 this Thursday 10:30am ABB 136 (this room)
#     - Practice Test posted
#     - 60 minutes
#     - 12 problems (multiple choice, short answer, long answer)
#     - Pre-recorded lecture following
# - Assignment 2 due today at 11:59pm (72hr grace period as always)s

# %% [markdown]
# ### Warmup
#
# Consider the sequence $(a_n)_{n\in \mathbb{N}}$. We can think of $(a_n)$ as a function taking as input a natural number $k$ and returning $a_k$ (the $k$-th term of the sequence).
#
# Write a function called `summer` which takes as input a function representing a sequence and maximum number of steps, and returns the partial sum up to this number of steps.

# %%
def seq(n : int) -> float :
    return 1/n**2

# %%
def summer(seq, max_steps):
    # YOUR CODE HERE
    # initialize the sum
    s = 0

    # counter
    i = 1

    while i <= max_steps:
        s += seq(i)
        i += 1
    return s

# %%
print(summer(seq,1000))
print(3.14**2/6)
# Out:
# 1.6439345666815615
# 1.6432666666666667

# %% [markdown]
# **Note:** This is an example of a function where we might want one of the inputs to have a **default** value.

# %%
def summer(seq, max_steps = 1000):
    # YOUR CODE HERE
    # initialize the sum
    s = 0

    # counter
    i = 1

    while i <= max_steps:
        s += seq(i)
        i += 1
    return s

# %%
print(summer(seq))
print(3.14**2/6)
# Out:
# 1.6439345666815615
# 1.6432666666666667

# %% [markdown]
# ## Adding documentation
# Ideally, the name of your function should give a clear indication of what it does.
# Technically, there is nothing wrong with the function below:

# %%
def sumFloat(a, b):
    return a*b

# %% [markdown]
# But it will lead to code that is impossible to understand.
#
# Sometimes, the name of the function if not sufficient to fully describe what it does. It is good practice to add a description of what a function does, how it does it etc.
# Python encourages this behaviour by automatically turning this description in to help. Note the triple quotes. These are used to allow text that spans multiple lines.

# %%
def sumFloat(a: float, b: float) -> float:
    '''
    Returns the sum of two floating point numbers. It is a bit of a silly function but
    it does a decent job at illustrating how python encourages documenting functions

    e.g.

    sumFloat(1.0, 2.2)
    >>> 3.2
    '''
    return a + b

# %%
help(sumFloat)
# Out:
# Help on function sumFloat in module __main__:
#
# sumFloat(a: float, b: float) -> float
#     Returns the sum of two floating point numbers. It is a bit of a silly function but
#     it does a decent job at illustrating how python encourages documenting functions
